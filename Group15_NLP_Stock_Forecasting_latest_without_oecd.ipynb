# %% [markdown]
# # Group-15 NLP Stock Forecasting
# ---
#
# *   Hongye Li / hongyeli@usc.edu
# *   Quanwei Gu / quanweig@usc.edu
# *   Yucen Xie / yucenxie@usc.edu
# *   Yunhao Han / yunhaoha@usc.edu
# *   Zhiqi Lu / zhiqilu@usc.edu
#
# ## Introduction
# This project implements an ensemble deep learning model for stock prediction using S&P 500 Index data and news data collected from CNBC.com, Reuters.com, WSJ.com, and Fortune.com. These datasets were partially obtained from the research of Xinyi et al.(2019) and Yang et al.(2022).

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/Shareddrives/CS544-Group15/project'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/Shareddrives/CS544-Group15/project

# %%
# install packages and import libs
# %pip install keras-self-attention
# %tensorflow_version 2.x
import json
import time
import math
import matplotlib.pyplot as plt
from math import pi,sqrt,exp,pow,log
from abc import ABCMeta, abstractmethod

import numpy as np
from numpy import newaxis
from numpy.linalg import det, inv
import pandas as pd
import datetime as dt
import matplotlib.dates as mdates
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

from keras_self_attention import SeqSelfAttention
from tensorflow import keras
from keras.layers import Dense, Activation, Dropout, LSTM, GRU, Conv1D, MaxPooling1D
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint

import statsmodels.api as sm 
import scipy.stats as scs
import scipy.optimize as sco
import scipy.interpolate as sci
from scipy import stats

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import Ridge
from sklearn import cluster
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import precision_recall_fscore_support, mean_squared_error, precision_score, recall_score, f1_score, classification_report, accuracy_score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras-self-attention in /usr/local/lib/python3.7/dist-packages (0.51.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention) (1.21.6)
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# read data
url = './data/source_price.csv'
stock_df= pd.read_csv(url)
stock_df.head()
# Out:
#          date  wsj_mean_compound  cnbc_mean_compound  fortune_mean_compound  \
# 0   2017/12/7              0.296             -0.1366                 0.0000
# 1   2017/12/8              0.000              0.0000                -0.2423
# 2  2017/12/11              0.000              0.0000                 0.0000
# 3  2017/12/12              0.000              0.0000                 0.0000
# 4  2017/12/13              0.000              0.0000                 0.0000
#
#    reuters_mean_compound    Adj Close
# 0                    0.0  2636.979980
# 1                    0.0  2651.500000
# 2                    0.0  2659.989990
# 3                    0.0  2664.110107
# 4                    0.0  2662.850098

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Dataset
#
# Our dataset contains 121 records/rows, where each one of them represents a trading day ranged from 2017-12-07 to 2018-06-01, and a total of 9 columns.
#
# * ```date```: date of each trading day (excluding weekends)
#
# *  ```Adj Close``` is the target value we want to predict, which represents the adjusted closing stock price for each trading day.
#
# * Columns with name ending with ```compound``` are sentiment scores generated using stock news gathered from different sources: WSJ, CNBC, Fortune and Reuters. These sentiment scores were computed using **Aware Dictionary and Sentiment Reasoner (VADER)**, which is a lexicon and rule-based model for general sen- timent analysis. VADER will give a compound score for each piece of news data, and the compound score is a metric that calculates the sum of all the lexicon ratings, which has a normalized value ranged in [-1, 1]. -1 means most extreme negative, 0 means neutral, and -1 means most extreme positive.
#
# * ```CLI, BCI, CCI```: Consumer Confidence Index (CCI), the Business Confidence Index (BCI), and the Composite Leading Indicator (CLI) are 3 leading economic indicators, provided by [OECD](https://data.oecd.org/leadind/consumer-confidence-index-cci.htm#indicator-chart), which can generally represent the current heath and performance of the current market.

# %%
# read data
url = './data/source_price.csv'
stock_df= pd.read_csv(url)
stock_df.head()
# Out:
#          date  wsj_mean_compound  cnbc_mean_compound  fortune_mean_compound  \
# 0   2017/12/7              0.296             -0.1366                 0.0000
# 1   2017/12/8              0.000              0.0000                -0.2423
# 2  2017/12/11              0.000              0.0000                 0.0000
# 3  2017/12/12              0.000              0.0000                 0.0000
# 4  2017/12/13              0.000              0.0000                 0.0000
#
#    reuters_mean_compound    Adj Close
# 0                    0.0  2636.979980
# 1                    0.0  2651.500000
# 2                    0.0  2659.989990
# 3                    0.0  2664.110107
# 4                    0.0  2662.850098

# %%
stock_df.tail()
# Out:
#           date  wsj_mean_compound  cnbc_mean_compound  fortune_mean_compound  \
# 116  2018/5/25           0.030290            0.047433               0.011550
# 117  2018/5/29          -0.052796            0.070442              -0.025721
# 118  2018/5/30          -0.017367            0.038119              -0.076965
# 119  2018/5/31          -0.018636            0.057371              -0.064138
# 120   2018/6/1           0.000000           -0.061150               0.361200
#
#      reuters_mean_compound    Adj Close
# 116              -0.025190  2721.330078
# 117              -0.035568  2689.860107
# 118              -0.063177  2724.010010
# 119              -0.025489  2705.270020
# 120              -0.004489  2734.620117

# %%
# use date as index
stock_df.index = stock_df.date
stock_df.drop('date', axis=1, inplace=True)

# %%
# nomalize adjust close stock price
adjust_close=stock_df['Adj Close'].values
# CLI=stock_df['CLI'].values
# BCI=stock_df['BCI'].values
# CCI=stock_df['CCI'].values
scaler = MinMaxScaler()
scaled_adjust_close = scaler.fit_transform(adjust_close.reshape(-1,1))
new_stock_df = stock_df.drop(['Adj Close'],axis=1)
new_stock_df['close_price'] = scaled_adjust_close

# new_stock_df['CLI'] = scaler.fit_transform(adjust_close.reshape(-1,1))
# new_stock_df['BCI'] = scaler.fit_transform(adjust_close.reshape(-1,1))
# new_stock_df['CCI'] = scaler.fit_transform(adjust_close.reshape(-1,1))
new_stock_df.head()
# Out:
#             wsj_mean_compound  cnbc_mean_compound  fortune_mean_compound  \
# date
# 2017/12/7               0.296             -0.1366                 0.0000
# 2017/12/8               0.000              0.0000                -0.2423
# 2017/12/11              0.000              0.0000                 0.0000
# 2017/12/12              0.000              0.0000                 0.0000
# 2017/12/13              0.000              0.0000                 0.0000
#
#             reuters_mean_compound  close_price
# date
# 2017/12/7                     0.0     0.191798
# 2017/12/8                     0.0     0.241546
# 2017/12/11                    0.0     0.270634
# 2017/12/12                    0.0     0.284750
# 2017/12/13                    0.0     0.280433

# %%
new_stock_df.shape
# Out:
# (121, 5)

# %% [markdown]
# ## Train-Validation-Test split
#
# Split data into 85% train-validation data and 15% test data.

# %%
# Train-test split. 85% train and 15% test
train_validation_data, test_data= train_test_split(new_stock_df, train_size=0.85, test_size=0.15,shuffle=False)

# %%
validation_data =train_validation_data[83:]
train_data=train_validation_data[:83]

print("Train data shape: ", train_data.shape)
print("Validation data shape: ", validation_data.shape)
print("Test data shape: ", test_data.shape)
# Out:
# Train data shape:  (83, 5)
# Validation data shape:  (19, 5)
# Test data shape:  (19, 5)

# %% [markdown]
# ## Time Series Data Processing
#
# Since the dataset we are working on uses date as index, and we need to deal with time series forecasting, which means we cannot use future data to make predictions on past data, we are using a sliding window with size=10 so that we can use the past 10 days to predict the next day.

# %%
look_back = 10 # sliding window size
forward_days = 1 # prediction size
NUM_NEURONS=50 # number of neurons per layer
EPOCHES=100 
BATCH_SIZE=32
DROUP_OUT=0.2

# %%
#Get the data and splits in input X and output Y, by spliting in `n` past days as input X 
#and `m` coming days as Y.
def getTimeSteps(data, look_back, forward_days,jump=1):
    x,y = [],[]
    for i in range(0,len(data) -look_back, jump):
        x.append(data[i:(i+look_back)])
        y.append(data[(i+look_back):(i+look_back+forward_days)])
    return np.array(x), np.array(y)

# %%
x_train,y_train = getTimeSteps(train_data.to_numpy(),look_back,forward_days)
x_validation,y_validation = getTimeSteps(validation_data.to_numpy(),look_back,forward_days)
x_test,y_test = getTimeSteps(test_data.to_numpy(),look_back,forward_days)

# %%
# extract only the close_price column as Y
y_train = y_train[:,0,-1]
y_validation = y_validation[:,0,-1]
y_test = y_test[:,0,-1]

print("y_train shape: ", y_train.shape)
print("y_validation shape: ", y_validation.shape)
print("y_test shape: ", y_test.shape)
# Out:
# y_train shape:  (73,)
# y_validation shape:  (9,)
# y_test shape:  (9,)

# %% [markdown]
# # Level-1 Models

# %% [markdown]
# ## LSTM model
#
# Built a LSTM model consists of four hidden layers, and each one contains 50 neurons. 0.2 drop-out layers were added between every two hidden layers. During each epoch, we computed the MSE and used Adam as optimizer.

# %%
# LSTM model
model1 = Sequential()
# layer 1
model1.add(LSTM(units=NUM_NEURONS, return_sequences = True, input_shape=(x_train.shape[1],x_train.shape[2])))
model1.add(Dropout(DROUP_OUT))
# layer 2
model1.add(LSTM(units=NUM_NEURONS, return_sequences = True))
model1.add(Dropout(DROUP_OUT))
# layer 3
model1.add(LSTM(units=NUM_NEURONS, return_sequences = True))
model1.add(Dropout(DROUP_OUT))
# layer 4
model1.add(LSTM(units=NUM_NEURONS))
model1.add(Dropout(DROUP_OUT))
# output layer
model1.add(Dense(forward_days))
# train
model1.compile(loss='mean_squared_error',optimizer='adam', metrics=['mse'])  
history1 =model1.fit(x_train, y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# collect training loss
model1_train_loss = history1.history['loss']
# Out:
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 12ms/sample - loss: 0.2688 - mean_squared_error: 0.2688
# Epoch 2/100
# 73/73 [==============================] - 0s 2ms/sample - loss: 0.1939 - mean_squared_error: 0.1939
# Epoch 3/100
# 73/73 [==============================] - 0s 808us/sample - loss: 0.1072 - mean_squared_error: 0.1072
# Epoch 4/100
# 73/73 [==============================] - 0s 960us/sample - loss: 0.0609 - mean_squared_error: 0.0609
# Epoch 5/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0909 - mean_squared_error: 0.0909
# Epoch 6/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0571 - mean_squared_error: 0.0571
# Epoch 7/100
# 73/73 [==============================] - 0s 988us/sample - loss: 0.0661 - mean_squared_error: 0.0661
# Epoch 8/100
# 73/73 [==============================] - 0s 794us/sample - loss: 0.0731 - mean_squared_error: 0.0731
# Epoch 9/100
# 73/73 [==============================] - 0s 830us/sample - loss: 0.0718 - mean_squared_error: 0.0718
# Epoch 10/100
# 73/73 [==============================] - 0s 806us/sample - loss: 0.0604 - mean_squared_error: 0.0604
# Epoch 11/100
# 73/73 [==============================] - 0s 744us/sample - loss: 0.0628 - mean_squared_error: 0.0628
# Epoch 12/100
# 73/73 [==============================] - 0s 781us/sample - loss: 0.0614 - mean_squared_error: 0.0614
# Epoch
100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0393 - mean_squared_error: 0.0393
# Epoch 64/100
# 73/73 [==============================] - 0s 913us/sample - loss: 0.0422 - mean_squared_error: 0.0422
# Epoch 65/100
# 73/73 [==============================] - 0s 740us/sample - loss: 0.0415 - mean_squared_error: 0.0415
# Epoch 66/100
# 73/73 [==============================] - 0s 763us/sample - loss: 0.0338 - mean_squared_error: 0.0338
# Epoch 67/100
# 73/73 [==============================] - 0s 763us/sample - loss: 0.0375 - mean_squared_error: 0.0375
# Epoch 68/100
# 73/73 [==============================] - 0s 783us/sample - loss: 0.0373 - mean_squared_error: 0.0373
# Epoch 69/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0366 - mean_squared_error: 0.0366
# Epoch 70/100
# 73/73 [==============================] - 0s 970us/sample - loss: 0.0412 - mean_squared_error: 0.0412
# Epoch 71/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 72/100
# 73/73 [==============================] - 0s 869us/sample - loss: 0.0312 - mean_squared_error: 0.0312
# Epoch 73/100
# 73/73 [==============================] - 0s 886us/sample - loss: 0.0398 - mean_squared_error: 0.0398
# Epoch 74/100
# 73/73 [==============================] - 0s 832us/sample - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 75/100
# 73/73 [==============================] - 0s 820us/sample - loss: 0.0292 - mean_squared_error: 0.0292
# Epoch 76/100
# 73/73 [==============================] - 0s 892us/sample - loss: 0.0260 - mean_squared_error: 0.0260
# Epoch 77/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0269 - mean_squared_error: 0.0269
# Epoch 78/100
# 73/73 [==============================] - 0s 912us/sample - loss: 0.0241 - mean_squared_error: 0.0241
# Epoch 79/100
# 73/73 [==============================] - 0s 963us/sample - loss: 0.0227 - mean_squared_error: 0.0227
# Epoch 80/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 81/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 82/100
# 73/73 [==============================] - 0s 2ms/sample - loss: 0.0309 - mean_squared_error: 0.0309
# Epoch 83/100
# 73/73 [==============================] - 0s 842us/sample - loss: 0.0313 - mean_squared_error: 0.0313
# Epoch 84/100
# 73/73 [==============================] - 0s 936us/sample - loss: 0.0279 - mean_squared_error: 0.0279
# Epoch 85/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0354 - mean_squared_error: 0.0354
# Epoch 86/100
# 73/73 [==============================] - 0s 887us/sample - loss: 0.0269 - mean_squared_error: 0.0269
# Epoch 87/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0272 - mean_squared_error: 0.0272
# Epoch 88/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0256 - mean_squared_error: 0.0256
# Epoch 89/100
# 73/73 [==============================] - 0s 862us/sample - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 90/100
# 73/73 [==============================] - 0s 746us/sample - loss: 0.0205 - mean_squared_error: 0.0205
# Epoch 91/100
# 73/73 [==============================] - 0s 841us/sample - loss: 0.0211 - mean_squared_error: 0.0211
# Epoch 92/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 93/100
# 73/73 [==============================] - 0s 872us/sample - loss: 0.0200 - mean_squared_error: 0.0200
# Epoch 94/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0210 - mean_squared_error: 0.0210
# Epoch 95/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0178 - mean_squared_error: 0.0178
# Epoch 96/100
# 73/73 [==============================] - 0s 873us/sample - loss: 0.0242 - mean_squared_error: 0.0242
# Epoch 97/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0185 - mean_squared_error: 0.0185
# Epoch 98/100
# 73/73 [==============================] - 0s 797us/sample - loss: 0.0167 - mean_squared_error: 0.0167
# Epoch 99/100
# 73/73 [==============================] - 0s 797us/sample - loss: 0.0174 - mean_squared_error: 0.0174
# Epoch 100/100
# 73/73 [==============================] - 0s 798us/sample - loss: 0.0184 - mean_squared_error: 0.0184

# %% [markdown]
# ## GRU Model
#
# Built a GRU model with similar structure to the previous LSTM model. Used RMSprop as Optimizer.

# %%
# GRU model
model2 = Sequential()
# layer 1
model2.add(GRU(units=NUM_NEURONS, return_sequences = True, input_shape=(x_train.shape[1],x_train.shape[2])))
model2.add(Dropout(DROUP_OUT))
# layer 2
model2.add(GRU(units=NUM_NEURONS, return_sequences = True))
model2.add(Dropout(DROUP_OUT))
# layer 3
model2.add(GRU(units=NUM_NEURONS, return_sequences = True))
model2.add(Dropout(DROUP_OUT))
# layer 4
model2.add(GRU(units=NUM_NEURONS))
model2.add(Dropout(DROUP_OUT))
# output layer
model2.add(Dense(forward_days))
# train
model2.compile(loss='mean_squared_error',optimizer='rmsprop')              
history2 =model2.fit(x_train, y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# collect training loss
model2_train_loss = history2.history['loss']
# Out:
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 11ms/sample - loss: 0.1468
# Epoch 2/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.
100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0174
# Epoch 94/100
# 73/73 [==============================] - 0s 895us/sample - loss: 0.0155
# Epoch 95/100
# 73/73 [==============================] - 0s 859us/sample - loss: 0.0150
# Epoch 96/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0129
# Epoch 97/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0196
# Epoch 98/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0235
# Epoch 99/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0165
# Epoch 100/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0190

# %% [markdown]
# ## Attention

# %%
# Attention model (with LSTM)
model3 = Sequential()
# layer 1
model3.add(LSTM(units=NUM_NEURONS, return_sequences = True, input_shape=(x_train.shape[1],x_train.shape[2])))
model3.add(Dropout(DROUP_OUT))
# layer 2
model3.add(SeqSelfAttention(attention_activation='sigmoid',attention_width=3, history_only=True, attention_type=SeqSelfAttention.ATTENTION_TYPE_MUL))
# layer 3
model3.add(LSTM(units=NUM_NEURONS))
model3.add(Dropout(DROUP_OUT))
# output layer
model3.add(Dense(forward_days))
# train 
model3.compile(loss='mean_squared_error', optimizer='adam')
history3 =model3.fit(x_train, y_train, epochs = EPOCHES, batch_size = BATCH_SIZE)
# collect training loss
model3_train_loss = history3.history['loss']
# Out:
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 1s 14ms/sample - loss: 0.2570
# Epoch 2/100
# 73/73 [==============================] - 0s 945us/sample - loss: 0.1693
# Epoch 3/100
# 73/73 [==============================] - 0s 794us/sample - loss: 0.1130
# Epoch 4/100
# 73/73 [==============================] - 0s 534us/sample - loss: 0.0648
# Epoch 5/100
# 73/73 [==============================] - 0s 675us/sample - loss: 0.0610
# Epoch 6/100
# 73/73 [==============================] - 0s 442us/sample - loss: 0.0606
# Epoch 7/100
# 73/73 [==============================] - 0s 482us/sample - loss: 0.0561
# Epoch 8/100
# 73/73 [==============================] - 0s 629us/sample - loss: 0.0549
# Epoch 9/100
# 73/73 [==============================] - 0s 542us/sample - loss: 0.0506
# Epoch 10/100
# 73/73 [==============================] - 0s 481us/sample - loss: 0.0561
# Epoch 11/100
# 73/73 [==============================] - 0s 476us/sample - loss: 0.0521
# Epoch 12/100
# 73/73 [==============================] - 0s 631us/sample - loss: 0.0501
# Epoch 13/100
# 73/73 [==============================] - 0s 609us/sample - loss: 0.0469
# Epoch 14/100
# 73/73 [==============================] - 0s 1ms/sample - loss: 0.0500
# Epoch 15/100
# 73/73 [==============================] - 0s 558us/sample - loss: 0.0571
# Epoch 16/100
# 73/73 [==============================] - 0s 478us/sample - loss: 0.0466
# Epoch 17/100
# 73/73 [==============================] - 0s 648us/sample - loss: 0.0535
# Epoch 18/100
# 73/73 [==============================] - 0s 550us/sample - loss: 0.0490
# Epoch 19/100
# 73/73 [==============================] - 0s 628us/sample - loss: 0.0481
# Epoch 20/100
# 73/73 [==============================] - 0s 770us/sample - loss: 0.0458
# Epoch 21/100
# 73/73 [==============================] - 0s 548us/sample - loss: 0.0437
# Epoch 22/100
# 73/73 [==============================] - 0s 613us/sample - loss: 0.0538
# Epoch 23/100
# 73/73 [==============================] - 0s 578us/sample - loss: 0.0441
# Epoch 24/100
# 73/73 [==============================] - 0s 526us/sample - loss: 0.0451
# Epoch 25/100
# 73/73 [==============================] - 0s 454us/sample - loss: 0.0440
# Epoch 26/100
# 73/73 [==============================] - 0s 986us/sample - loss: 0.0155

# %% [markdown]
# ## CNN_LSTM

# %%
# build CNN_LSTM model
model4 = Sequential()
# conv layer
model4.add(Conv1D(filters=32, kernel_size=1, activation='tanh', padding='same', input_shape=(10, 5)))
# maxpooling layer
model4.add(MaxPooling1D(pool_size=1, padding='same'))
# LSTM layer
model4.add(LSTM(units=NUM_NEURONS, activation='tanh'))
model4.add(Dropout(DROUP_OUT))
# output layer
model4.add(Dense(forward_days))
# train model
model4.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae'])
history4 = model4.fit(x_train, y_train, epochs=EPOCHES, batch_size=64, verbose=1, shuffle =True)
# Out:
# Train on 73 samples
# Epoch 1/100
# 73/73 [==============================] - 0s 3ms/sample - loss: 0.4016 - mean_squared_error: 0.4016 - mean_absolute_error: 0.5750
# Epoch 2/100
# 73/73 [==============================] - 0s 195us/sample - loss: 0.2477 - mean_squared_error: 0.2477 - mean_absolute_error: 0.4389
# Epoch 3/100
# 73/73 [==============================] - 0s 212us/sample - loss: 0.1355 - mean_squared_error: 0.1355 - mean_absolute_error: 0.3211
# Epoch 4/100
# 73/73 [==============================] - 0s 198us/sample - loss: 0.0619 - mean_squared_error: 0.0619 - mean_absolute_error: 0.2102
# Epoch 5/100
# 73/73 [==============================] - 0s 194us/sample - loss: 0.0400 - mean_squared_error: 0.0400 - mean_absolute_error: 0.1549
# Epoch 6/100
# 73/73 [==============================] - 0s 219us/sample - loss: 0.0462 - mean_squared_error: 0.0462 - mean_absolute_error: 0.1520
# Epoch 7/100
# 73/73 [==============================] - 0s 230us/sample - loss: 0.0484 - mean_squared_error: 0.0484 - mean_absolute_error: 0.1707
# Epoch 8/100
# 73/73 [==============================] - 0s 208us/sample - loss: 0.0641 - mean_squared_error: 0.0641 - mean_absolute_error: 0.1817
# Epoch 9/100
# 73/73 [==============================] - 0s 205us/sample - loss: 0.0549 - mean_squared_error: 0.0549 - mean_absolute_error: 0.1616
# Epoch 10/100
# 73/73 [==============================] - 0s 230us/sample - loss: 0.0517 - mean_squared_error: 0.0517 - mean_absolute_error: 0.1656
# Epoch 11/100
# 73/73 [==============================] - 0s 218us/sample - loss: 0.0291 - mean_squared_error: 0.0291 - mean_absolute_error: 0.1238
# Epoch 12/100
# 73/73 [==============================] - 0s 207us/sample - loss: 0.0279 - mean_squared_error: 0.0279 - mean_absolute_error: 0.1270
# Epoch 13/100
# 73/73 [==============================] - 0s 229us/sample - loss: 0.0314 - mean_squared_error: 0.0314 - mean_absolute_error: 0.1349
# Epoch 14/100
# 73/73 [==============================] - 0s 234us/sample - loss: 0.0366 - mean_squared_error: 0.0366 - mean_absolute_error: 0.1507
# Epoch 15/100
# 73/73 [==============================] - 0s 289us/sample - loss: 0.0321 - mean_squared_error: 0.0321 - mean_absolute_error: 0.1443
# Epoch 16/100
# 73/73 [==============================] - 0s 183us/sample - loss: 0.0377 - mean_squared_error: 0.0377 - mean_absolute_error: 0.1596
# Epoch 17/100
# 73/73 [==============================] - 0s 188us/sample - loss: 0.0281 - mean_squared_error: 0.0281 - mean_absolute_error: 0.1365
# Epoch 18/100
# 73/73 [==============================] - 0s 246us/sample - loss: 0.0335 - mean_squared_error: 0.0335 - mean_absolute_error: 0.1421
# Epoch 19/100
# 73/73 [==============================] - 0s 285us/sample - loss: 0.0300 - mean_squared_error: 0.0300 - mean_absolute_error: 0.1326
# Epoch 20/100
- mean_squared_error: 0.0129 - mean_absolute_error: 0.0880
# Epoch 90/100
# 73/73 [==============================] - 0s 206us/sample - loss: 0.0190 - mean_squared_error: 0.0190 - mean_absolute_error: 0.1046
# Epoch 91/100
# 73/73 [==============================] - 0s 195us/sample - loss: 0.0129 - mean_squared_error: 0.0129 - mean_absolute_error: 0.0863
# Epoch 92/100
# 73/73 [==============================] - 0s 217us/sample - loss: 0.0171 - mean_squared_error: 0.0171 - mean_absolute_error: 0.1032
# Epoch 93/100
# 73/73 [==============================] - 0s 284us/sample - loss: 0.0153 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0961
# Epoch 94/100
# 73/73 [==============================] - 0s 454us/sample - loss: 0.0174 - mean_squared_error: 0.0174 - mean_absolute_error: 0.0961
# Epoch 95/100
# 73/73 [==============================] - 0s 213us/sample - loss: 0.0157 - mean_squared_error: 0.0157 - mean_absolute_error: 0.0991
# Epoch 96/100
# 73/73 [==============================] - 0s 247us/sample - loss: 0.0120 - mean_squared_error: 0.0120 - mean_absolute_error: 0.0821
# Epoch 97/100
# 73/73 [==============================] - 0s 195us/sample - loss: 0.0138 - mean_squared_error: 0.0138 - mean_absolute_error: 0.0910
# Epoch 98/100
# 73/73 [==============================] - 0s 250us/sample - loss: 0.0138 - mean_squared_error: 0.0138 - mean_absolute_error: 0.0871
# Epoch 99/100
# 73/73 [==============================] - 0s 258us/sample - loss: 0.0142 - mean_squared_error: 0.0142 - mean_absolute_error: 0.0958
# Epoch 100/100
# 73/73 [==============================] - 0s 206us/sample - loss: 0.0114 - mean_squared_error: 0.0114 - mean_absolute_error: 0.0828

# %%
# make predictions on Validation data
y_hat_validation_1 = model1.predict(x_validation)
y_hat_validation_2 = model2.predict(x_validation)
y_hat_validation_3 = model3.predict(x_validation)
y_hat_validation_4 = model4.predict(x_validation)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2067: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# Undo the scaling
y_validation = y_validation.reshape(-1,1)
y_validation_unscaled = scaler.inverse_transform(y_validation)
y_validation.reshape(-1,1)
# Out:
# array([[0.18350648],
#        [0.20008866],
#        [0.29444584],
#        [0.3046215 ],
#        [0.22972564],
#        [0.25285236],
#        [0.18730908],
#        [0.16695776],
#        [0.28238561]])

# %%
y_validation_unscaled
# Out:
# array([[2634.560059],
#        [2639.399902],
#        [2666.939941],
#        [2669.909912],
#        [2648.050049],
#        [2654.800049],
#        [2635.669922],
#        [2629.72998 ],
#        [2663.419922]])

# %%
y_hat_validation_1 = scaler.inverse_transform(y_hat_validation_1)
y_hat_validation_2 = scaler.inverse_transform(y_hat_validation_2)
y_hat_validation_3 = scaler.inverse_transform(y_hat_validation_3)
y_hat_validation_4 = scaler.inverse_transform(y_hat_validation_4)

# %%
# make predictions on test data use level-1 models repectively
y_hat_test_1 = model1.predict(x_test) # test LSTM
y_hat_test_2 = model2.predict(x_test) # test GRU
y_hat_test_3 = model3.predict(x_test) # test Attention
y_hat_test_4 = model4.predict(x_test) # test CNN

y_hat_test_1 = scaler.inverse_transform(y_hat_test_1)
y_hat_test_2 = scaler.inverse_transform(y_hat_test_2)
y_hat_test_3 = scaler.inverse_transform(y_hat_test_3)
y_hat_test_4 = scaler.inverse_transform(y_hat_test_4)

y_test = y_test.reshape(-1,1)
y_test = scaler.inverse_transform(y_test)

# %%
y_test
# Out:
# array([[2733.01001 ],
#        [2724.439941],
#        [2733.290039],
#        [2727.76001 ],
#        [2721.330078],
#        [2689.860107],
#        [2724.01001 ],
#        [2705.27002 ],
#        [2734.620117]])

# %%
LSTM_mse =  mean_squared_error(y_hat_test_1, y_test)
GRU_mse = mean_squared_error(y_hat_test_2, y_test)
Attention_mse = mean_squared_error(y_hat_test_3, y_test)
CNN_mse = mean_squared_error(y_hat_test_4, y_test)
print("LSTM model test MSE: ", LSTM_mse)
print("GRU model test MSE: ", GRU_mse)
print("Attention test MSE: ", Attention_mse)
print("CNN test MSE: ", CNN_mse)
# Out:
# LSTM model test MSE:  288.5750590178285
# GRU model test MSE:  536.9837994145817
# Attention test MSE:  372.974693928619
# CNN test MSE:  274.2241130831379

# %% [markdown]
# # Level-2 Blending Ensemble Model

# %% [markdown]
# ## Previous Work

# %% [markdown]
# After we obtain the preditions of validation data for all 4 level-1 models, we combine them together into a new training dataset. This new dataset will be passed to the second level to train the meta-learner(level-2 model). We first implemented the previous LSTM_GRU ensemble model.
#
# ---

# %%
ensemble_model_prev = keras.Sequential([
    keras.layers.Flatten(input_shape=(2,)),
    keras.layers.Dense(18, activation='relu'),
    keras.layers.Dense(9, activation='relu'),
    keras.layers.Dense(2, activation='relu'),
    keras.layers.Dense(1)
])

# %%
ensemble_model_prev.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=['mae'])

# %%
scaler_prev = MinMaxScaler()
scaled_y_hat_validation_1 = scaler_prev.fit_transform(y_hat_validation_1)
scaled_y_hat_validation_2 = scaler_prev.fit_transform(y_hat_validation_2)
scaled_y_validation = scaler_prev.fit_transform(y_validation_unscaled)

# combine three validation predictions as new train dataset for the ensemble model
train_data_level2_prev = np.concatenate((scaled_y_hat_validation_1, scaled_y_hat_validation_2), axis=-1)

# %%
ensemble_model_prev.fit(train_data_level2_prev, scaled_y_validation, epochs=100, batch_size=2)
# Out:
# Train on 9 samples
# Epoch 1/100
# 9/9 [==============================] - 0s 13ms/sample - loss: 0.3580 - mean_absolute_error: 0.4803
# Epoch 2/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3510 - mean_absolute_error: 0.4754
# Epoch 3/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3457 - mean_absolute_error: 0.4707
# Epoch 4/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3414 - mean_absolute_error: 0.4671
# Epoch 5/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3368 - mean_absolute_error: 0.4635
# Epoch 6/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3326 - mean_absolute_error: 0.4601
# Epoch 7/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3283 - mean_absolute_error: 0.4564
# Epoch 8/100
# 9/9 [==============================] - 0s 936us/sample - loss: 0.3246 - mean_absolute_error: 0.4527
# Epoch 9/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.3211 - mean_absolute_error: 0.4495
# Epoch 10/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3173 - mean_absolute_error: 0.4465
# Epoch 11/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.3140 - mean_absolute_error: 0.4435
# Epoch 12/100
# 9/9 [==============================] - 0s 964us/sample - loss: 0.3098 - mean_absolute_error: 0.4401
# Epoch 13/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3063 - mean_absolute_error: 0.4362
# Epoch 14/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3032 - mean_absolute_error: 0.4336
# Epoch 15/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.3001 - mean_absolute_error: 0.4298
# Epoch 16/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2967 - mean_absolute_error: 0.4276
# Epoch 17/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2929 - mean_absolute_error: 0.4237
# Epoch 18/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2895 - mean_absolute_error: 0.4211
# Epoch 19/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2865 - mean_absolute_error: 0.4180
# Epoch 20/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2832 - mean_absolute_error: 0.4148
# Epoch 21/100
# 9/9 [==============================] - 0s 985us/sample - loss: 0.2795 - mean_absolute_error: 0.4107
# Epoch 22/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2761 - mean_absolute_error: 0.4077
# Epoch 23/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2728 - mean_absolute_error: 0.4038
# Epoch 24/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2699 - mean_absolute_error: 0.4009
# Epoch 25/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2668 - mean_absolute_error: 0.3976
# Epoch 26/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2639 - mean_absolute_error: 0.3945
# Epoch 27/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.2611 - mean_absolute_error: 0.3919
# Epoch 28/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2582 - mean_absolute_error: 0.3890
# Epoch 29/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2554 - mean_absolute_error: 0.3869
# Epoch 30/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2527 - mean_absolute_error: 0.3848
# Epoch 31/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2498 - mean_absolute_error: 0.3823
# Epoch 32/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2473 - mean_absolute_error: 0.3801
# Epoch 33/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2445 - mean_absolute_error: 0.3785
# Epoch 34/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2415 - mean_absolute_error: 0.3758
# Epoch 35/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2389 - mean_absolute_error: 0.3741
# Epoch 36/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2367 - mean_absolute_error: 0.3731
# Epoch 37/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2345 - mean_absolute_error: 0.3724
# Epoch 38/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.2321 - mean_absolute_error: 0.3713
# Epoch 39/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2297 - mean_absolute_error: 0.3695
# Epoch 40/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2275 - mean_absolute_error: 0.3687
# Epoch 41/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2253 - mean_absolute_error: 0.3672
# Epoch 42/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2232 - mean_absolute_error: 0.3660
# Epoch 43/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2208 - mean_absolute_error: 0.3648
# Epoch 44/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2185 - mean_absolute_error: 0.3633
# Epoch 45/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2162 - mean_absolute_error: 0.3623
# Epoch 46/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.2144 - mean_absolute_error: 0.3614
# Epoch 47/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2125 - mean_absolute_error: 0.3603
# Epoch 48/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2102 - mean_absolute_error: 0.3588
# Epoch 49/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2078 - mean_absolute_error: 0.3574
# Epoch 50/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2059 - mean_absolute_error: 0.3565
# Epoch 51/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2044 - mean_absolute_error: 0.3557
# Epoch 52/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2026 - mean_absolute_error: 0.3541
# Epoch 53/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2009 - mean_absolute_error: 0.3533
# Epoch 54/100
# 9/9 [==============================] - 0s 3ms/sample - loss: 0.1993 - mean_absolute_error: 0.3523
# Epoch 55/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1972 - mean_absolute_error: 0.3506
# Epoch 56/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1955 - mean_absolute_error: 0.3500
# Epoch 57/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.1934 - mean_absolute_error: 0.3484
# Epoch 58/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1913 - mean_absolute_error: 0.3470
# Epoch 59/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1899 - mean_absolute_error: 0.3465
# Epoch 60/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1882 - mean_absolute_error: 0.3451
# Epoch 61/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1865 - mean_absolute_error: 0.3438
# Epoch 62/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1846 - mean_absolute_error: 0.3433
# Epoch 63/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1829 - mean_absolute_error: 0.3434
# Epoch 64/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1816 - mean_absolute_error: 0.3423
# Epoch 65/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1801 - mean_absolute_error: 0.3426
# Epoch 66/100
# 9/9 [==============================] - 0s 990us/sample - loss: 0.1787 - mean_absolute_error: 0.3422
# Epoch 67/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1773 - mean_absolute_error: 0.3416
# Epoch 68/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1757 - mean_absolute_error: 0.3415
# Epoch 69/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1743 - mean_absolute_error: 0.3415
# Epoch 70/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1733 - mean_absolute_error: 0.3410
# Epoch 71/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1720 - mean_absolute_error: 0.3402
# Epoch 72/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1706 - mean_absolute_error: 0.3404
# Epoch 73/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1694 - mean_absolute_error: 0.3395
# Epoch 74/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.1680 - mean_absolute_error: 0.3394
# Epoch 75/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1665 - mean_absolute_error: 0.3391
# Epoch 76/100
# 9/9 [==============================] - 0s 957us/sample - loss: 0.1658 - mean_absolute_error: 0.3386
# Epoch 77/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1647 - mean_absolute_error: 0.3386
# Epoch 78/100
# 9/9 [==============================] - 0s 945us/sample - loss: 0.1636 - mean_absolute_error: 0.3383
# Epoch 79/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1623 - mean_absolute_error: 0.3377
# Epoch 80/100
# 9/9 [==============================] - 0s 978us/sample - loss: 0.1613 - mean_absolute_error: 0.3373
# Epoch 81/100
# 9/9 [==============================] - 0s 992us/sample - loss: 0.1603 - mean_absolute_error: 0.3374
# Epoch 82/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1593 - mean_absolute_error: 0.3366
# Epoch 83/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1582 - mean_absolute_error: 0.3366
# Epoch 84/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1574 - mean_absolute_error: 0.3362
# Epoch 85/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1562 - mean_absolute_error: 0.3359
# Epoch 86/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1554 - mean_absolute_error: 0.3356
# Epoch 87/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1547 - mean_absolute_error: 0.3357
# Epoch 88/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1539 - mean_absolute_error: 0.3351
# Epoch 89/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1534 - mean_absolute_error: 0.3346
# Epoch 90/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1525 - mean_absolute_error: 0.3345
# Epoch 91/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.1517 - mean_absolute_error: 0.3342
# Epoch 92/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1513 - mean_absolute_error: 0.3342
# Epoch 93/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1507 - mean_absolute_error: 0.3341
# Epoch 94/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1501 - mean_absolute_error: 0.3338
# Epoch 95/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1495 - mean_absolute_error: 0.3338
# Epoch 96/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1493 - mean_absolute_error: 0.3337
# Epoch 97/100
# 9/9 [==============================] - 0s 971us/sample - loss: 0.1488 - mean_absolute_error: 0.3331
# Epoch 98/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1478 - mean_absolute_error: 0.3327
# Epoch 99/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1474 - mean_absolute_error: 0.3330
# Epoch 100/100
# 9/9 [==============================] - 0s 985us/sample - loss: 0.1469 - mean_absolute_error: 0.3326

# %% [markdown]
# Next, we combine the test predictions generated by level-1 sub-models into a new test dataset. The meta-learner will make final predictions on this new test dataset.

# %%
# combine test predictions generated by level1 sub-models
scaled_y_hat_test_1 = scaler_prev.fit_transform(y_hat_test_1)
scaled_y_hat_test_2 = scaler_prev.fit_transform(y_hat_test_2)

test_data_level2_prev = np.concatenate((scaled_y_hat_test_1, scaled_y_hat_test_2), axis=-1)

# %%
y_hat_ensemble_prev = ensemble_model_prev.predict(test_data_level2_prev)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2067: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# undo the scaling to get the valid stock price
ensemble_predicted_stock_price_prev = scaler_prev.inverse_transform(y_hat_ensemble_prev)
ensemble_predicted_stock_price_prev
# Out:
# array([[2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717],
#        [2699.2717]], dtype=float32)

# %%
ensemble_mse_prev = mean_squared_error(ensemble_predicted_stock_price_prev, y_test)
print("MSE of the Previous Blending Ensemble: ", ensemble_mse_prev)
# Out:
# MSE of the Previous Blending Ensemble:  690.3509143137828

# %% [markdown]
# ## Current Work

# %% [markdown]
# After we obtain the preditions of validation data for all 4 level-1 models, we combine them together into a new training dataset. This new dataset will be passed to the second level to train the meta-learner(level-2 model). We then implemented our LSTM_GRU_Attension_CNNLSTM ensemble model.
#
# ---

# %%
ensemble_model = keras.Sequential([
    keras.layers.Flatten(input_shape=(4,)),
    keras.layers.Dense(18, activation='relu'),
    keras.layers.Dense(9, activation='relu'),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1)
])

# %%
ensemble_model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=['mae'])

# %%
scaler = MinMaxScaler()
scaled_y_hat_validation_1 = scaler.fit_transform(y_hat_validation_1)
scaled_y_hat_validation_2 = scaler.fit_transform(y_hat_validation_2)
scaled_y_hat_validation_3 = scaler.fit_transform(y_hat_validation_3)
scaled_y_hat_validation_4 = scaler.fit_transform(y_hat_validation_4)
scaled_y_validation = scaler.fit_transform(y_validation_unscaled)

# combine three validation predictions as new train dataset for the ensemble model
train_data_level2 = np.concatenate((scaled_y_hat_validation_1, scaled_y_hat_validation_2, scaled_y_hat_validation_3, scaled_y_hat_validation_4), axis=-1)

# %%
ensemble_model.fit(train_data_level2, scaled_y_validation, epochs=100, batch_size=2)
# Out:
# Train on 9 samples
# Epoch 1/100
# 9/9 [==============================] - 0s 13ms/sample - loss: 0.2629 - mean_absolute_error: 0.4302
# Epoch 2/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2507 - mean_absolute_error: 0.4042
# Epoch 3/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2372 - mean_absolute_error: 0.3976
# Epoch 4/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.2212 - mean_absolute_error: 0.3944
# Epoch 5/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.2087 - mean_absolute_error: 0.3930
# Epoch 6/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1988 - mean_absolute_error: 0.3883
# Epoch 7/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1891 - mean_absolute_error: 0.3819
# Epoch 8/100
# 9/9 [==============================] - 0s 924us/sample - loss: 0.1811 - mean_absolute_error: 0.3724
# Epoch 9/100
# 9/9 [==============================] - 0s 957us/sample - loss: 0.1714 - mean_absolute_error: 0.3669
# Epoch 10/100
# 9/9 [==============================] - 0s 978us/sample - loss: 0.1638 - mean_absolute_error: 0.3627
# Epoch 11/100
# 9/9 [==============================] - 0s 925us/sample - loss: 0.1644 - mean_absolute_error: 0.3628
# Epoch 12/100
# 9/9 [==============================] - 0s 928us/sample - loss: 0.1576 - mean_absolute_error: 0.3581
# Epoch 13/100
# 9/9 [==============================] - 0s 997us/sample - loss: 0.1520 - mean_absolute_error: 0.3529
# Epoch 14/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1471 - mean_absolute_error: 0.3465
# Epoch 15/100
# 9/9 [==============================] - 0s 912us/sample - loss: 0.1469 - mean_absolute_error: 0.3483
# Epoch 16/100
# 9/9 [==============================] - 0s 944us/sample - loss: 0.1414 - mean_absolute_error: 0.3424
# Epoch 17/100
# 9/9 [==============================] - 0s 948us/sample - loss: 0.1383 - mean_absolute_error: 0.3398
# Epoch 18/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1368 - mean_absolute_error: 0.3358
# Epoch 19/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1349 - mean_absolute_error: 0.3353
# Epoch 20/100
# 9/9 [==============================] - 0s 965us/sample - loss: 0.1276 - mean_absolute_error: 0.3254
# Epoch 21/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1287 - mean_absolute_error: 0.3279
# Epoch 22/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1262 - mean_absolute_error: 0.3251
# Epoch 23/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1220 - mean_absolute_error: 0.3186
# Epoch 24/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1179 - mean_absolute_error: 0.3134
# Epoch 25/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1190 - mean_absolute_error: 0.3098
# Epoch 26/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1164 - mean_absolute_error: 0.3105
# Epoch 27/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1152 - mean_absolute_error: 0.3069
# Epoch 28/100
# 9/9 [==============================] - 0s 968us/sample - loss: 0.1109 - mean_absolute_error: 0.2998
# Epoch 29/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1113 - mean_absolute_error: 0.3028
# Epoch 30/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.1061 - mean_absolute_error: 0.2959
# Epoch 31/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1062 - mean_absolute_error: 0.2940
# Epoch 32/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1060 - mean_absolute_error: 0.2920
# Epoch 33/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.1006 - mean_absolute_error: 0.2829
# Epoch 34/100
# 9/9 [==============================] - 0s 961us/sample - loss: 0.1013 - mean_absolute_error: 0.2859
# Epoch 35/100
# 9/9 [==============================] - 0s 973us/sample - loss: 0.0992 - mean_absolute_error: 0.2822
# Epoch 36/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0954 - mean_absolute_error: 0.2791
# Epoch 37/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0971 - mean_absolute_error: 0.2792
# Epoch 38/100
# 9/9 [==============================] - 0s 967us/sample - loss: 0.0949 - mean_absolute_error: 0.2735
# Epoch 39/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0928 - mean_absolute_error: 0.2702
# Epoch 40/100
# 9/9 [==============================] - 0s 989us/sample - loss: 0.0905 - mean_absolute_error: 0.2650
# Epoch 41/100
# 9/9 [==============================] - 0s 987us/sample - loss: 0.0902 - mean_absolute_error: 0.2697
# Epoch 42/100
# 9/9 [==============================] - 0s 988us/sample - loss: 0.0887 - mean_absolute_error: 0.2697
# Epoch 43/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0884 - mean_absolute_error: 0.2636
# Epoch 44/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0890 - mean_absolute_error: 0.2626
# Epoch 45/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0843 - mean_absolute_error: 0.2523
# Epoch 46/100
# 9/9 [==============================] - 0s 978us/sample - loss: 0.0850 - mean_absolute_error: 0.2545
# Epoch 47/100
# 9/9 [==============================] - 0s 997us/sample - loss: 0.0817 - mean_absolute_error: 0.2496
# Epoch 48/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0815 - mean_absolute_error: 0.2426
# Epoch 49/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0812 - mean_absolute_error: 0.2512
# Epoch 50/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0787 - mean_absolute_error: 0.2443
# Epoch 51/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0776 - mean_absolute_error: 0.2494
# Epoch 52/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0757 - mean_absolute_error: 0.2407
# Epoch 53/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0756 - mean_absolute_error: 0.2341
# Epoch 54/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0745 - mean_absolute_error: 0.2395
# Epoch 55/100
# 9/9 [==============================] - 0s 985us/sample - loss: 0.0736 - mean_absolute_error: 0.2317
# Epoch 56/100
# 9/9 [==============================] - 0s 998us/sample - loss: 0.0718 - mean_absolute_error: 0.2328
# Epoch 57/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0713 - mean_absolute_error: 0.2314
# Epoch 58/100
# 9/9 [==============================] - 0s 990us/sample - loss: 0.0719 - mean_absolute_error: 0.2242
# Epoch 59/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0717 - mean_absolute_error: 0.2240
# Epoch 60/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0694 - mean_absolute_error: 0.2246
# Epoch 61/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0684 - mean_absolute_error: 0.2249
# Epoch 62/100
# 9/9 [==============================] - 0s 977us/sample - loss: 0.0671 - mean_absolute_error: 0.2190
# Epoch 63/100
# 9/9 [==============================] - 0s 997us/sample - loss: 0.0655 - mean_absolute_error: 0.2168
# Epoch 64/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0663 - mean_absolute_error: 0.2156
# Epoch 65/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0680 - mean_absolute_error: 0.2248
# Epoch 66/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0659 - mean_absolute_error: 0.2112
# Epoch 67/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0642 - mean_absolute_error: 0.2138
# Epoch 68/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0638 - mean_absolute_error: 0.2171
# Epoch 69/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0632 - mean_absolute_error: 0.2094
# Epoch 70/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0619 - mean_absolute_error: 0.2104
# Epoch 71/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.0617 - mean_absolute_error: 0.2086
# Epoch 72/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0600 - mean_absolute_error: 0.2034
# Epoch 73/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0580 - mean_absolute_error: 0.1975
# Epoch 74/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0593 - mean_absolute_error: 0.2018
# Epoch 75/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0586 - mean_absolute_error: 0.2024
# Epoch 76/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0590 - mean_absolute_error: 0.1996
# Epoch 77/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0574 - mean_absolute_error: 0.1954
# Epoch 78/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0567 - mean_absolute_error: 0.1964
# Epoch 79/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0565 - mean_absolute_error: 0.1976
# Epoch 80/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0562 - mean_absolute_error: 0.1972
# Epoch 81/100
# 9/9 [==============================] - 0s 988us/sample - loss: 0.0547 - mean_absolute_error: 0.1926
# Epoch 82/100
# 9/9 [==============================] - 0s 2ms/sample - loss: 0.0547 - mean_absolute_error: 0.1904
# Epoch 83/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0546 - mean_absolute_error: 0.1916
# Epoch 84/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0518 - mean_absolute_error: 0.1894
# Epoch 85/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0537 - mean_absolute_error: 0.1927
# Epoch 86/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0537 - mean_absolute_error: 0.1932
# Epoch 87/100
# 9/9 [==============================] - 0s 985us/sample - loss: 0.0518 - mean_absolute_error: 0.1873
# Epoch 88/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0507 - mean_absolute_error: 0.1852
# Epoch 89/100
# 9/9 [==============================] - 0s 990us/sample - loss: 0.0508 - mean_absolute_error: 0.1839
# Epoch 90/100
# 9/9 [==============================] - 0s 986us/sample - loss: 0.0484 - mean_absolute_error: 0.1811
# Epoch 91/100
# 9/9 [==============================] - 0s 983us/sample - loss: 0.0487 - mean_absolute_error: 0.1798
# Epoch 92/100
# 9/9 [==============================] - 0s 994us/sample - loss: 0.0481 - mean_absolute_error: 0.1814
# Epoch 93/100
# 9/9 [==============================] - 0s 978us/sample - loss: 0.0492 - mean_absolute_error: 0.1839
# Epoch 94/100
# 9/9 [==============================] - 0s 988us/sample - loss: 0.0468 - mean_absolute_error: 0.1772
# Epoch 95/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0477 - mean_absolute_error: 0.1800
# Epoch 96/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0464 - mean_absolute_error: 0.1752
# Epoch 97/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0462 - mean_absolute_error: 0.1762
# Epoch 98/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0463 - mean_absolute_error: 0.1783
# Epoch 99/100
# 9/9 [==============================] - 0s 1ms/sample - loss: 0.0441 - mean_absolute_error: 0.1697
# Epoch 100/100
# 9/9 [==============================] - 0s 984us/sample - loss: 0.0454 - mean_absolute_error: 0.1748

# %% [markdown]
# Next, we combine the test predictions generated by level-1 sub-models into a new test dataset. The meta-learner will make final predictions on this new test dataset.

# %%
# combine test predictions generated by level1 sub-models
scaled_y_hat_test_1 = scaler.fit_transform(y_hat_test_1)
scaled_y_hat_test_2 = scaler.fit_transform(y_hat_test_2)
scaled_y_hat_test_3 = scaler.fit_transform(y_hat_test_3)
scaled_y_hat_test_4 = scaler.fit_transform(y_hat_test_4)

test_data_level2 = np.concatenate((scaled_y_hat_test_1, scaled_y_hat_test_2, scaled_y_hat_test_3, scaled_y_hat_test_4), axis=-1)

# %%
y_hat_ensemble = ensemble_model.predict(test_data_level2)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/training_v1.py:2067: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,

# %%
# undo the scaling to get the valid stock price
ensemble_predicted_stock_price = scaler.inverse_transform(y_hat_ensemble)
ensemble_predicted_stock_price
# Out:
# array([[2713.6665],
#        [2710.8606],
#        [2709.1094],
#        [2712.6758],
#        [2712.379 ],
#        [2710.3247],
#        [2718.142 ],
#        [2716.8223],
#        [2715.7944]], dtype=float32)

# %%
ensemble_mse = mean_squared_error(ensemble_predicted_stock_price, y_test)
print("MSE of the Blending Ensemble: ", ensemble_mse)
# Out:
# MSE of the Blending Ensemble:  265.7805407715286

# %% [markdown]
# # Result Analysis

# %%
def format_score(y_tf, Y_tf, y, Y):
  report = classification_report(y_tf, Y_tf, output_dict=True)
  label = 'weighted avg'
  mpa = round(float(1 - sum(abs(Y-y) / Y) / len(y)), 6)
  mda = accuracy_score(y_tf, Y_tf)
  return [mpa, report[label]['precision'], report[label]['recall'], report[label]['f1-score'], mda]

m_trends = np.zeros((6, len(y_hat_test_1) - 1))
actual_trends = np.zeros(len(y_hat_test_1) - 1)
for i in range(1, len(y_hat_test_1)):
  m_trends[0][i - 1] = y_hat_test_1[i] > y_hat_test_1[i - 1]
  m_trends[1][i - 1] = y_hat_test_2[i] > y_hat_test_2[i - 1]
  m_trends[2][i - 1] = y_hat_test_3[i] > y_hat_test_3[i - 1]
  m_trends[3][i - 1] = y_hat_test_4[i] > y_hat_test_4[i - 1]
  m_trends[4][i - 1] = ensemble_predicted_stock_price_prev[i] > ensemble_predicted_stock_price_prev[i - 1]
  m_trends[5][i - 1] = ensemble_predicted_stock_price[i] > ensemble_predicted_stock_price[i - 1]
  actual_trends[i - 1] = y_test[i] > y_test[i - 1]

LSTM_scores = format_score(m_trends[0], actual_trends, y_hat_test_1, y_test)
GRU_scores = format_score(m_trends[1], actual_trends, y_hat_test_2, y_test)
Attention_scores = format_score(m_trends[2], actual_trends, y_hat_test_3, y_test)
CNN_scores = format_score(m_trends[3], actual_trends, y_hat_test_4, y_test)
prev_ensemble_scores = format_score(m_trends[4], actual_trends, ensemble_predicted_stock_price_prev, y_test)
curr_ensemble_scores = format_score(m_trends[5], actual_trends, ensemble_predicted_stock_price, y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Table
# MSE, MPA, Precision, Recall, F1-score, MDA
data = [
    [LSTM_mse, GRU_mse, Attention_mse, CNN_mse, ensemble_mse_prev, ensemble_mse],
    [LSTM_scores[0], GRU_scores[0], Attention_scores[0], CNN_scores[0], prev_ensemble_scores[0], curr_ensemble_scores[0]],
    [LSTM_scores[1], GRU_scores[1], Attention_scores[1], CNN_scores[1], prev_ensemble_scores[1], curr_ensemble_scores[1]],
    [LSTM_scores[2], GRU_scores[2], Attention_scores[2], CNN_scores[2], prev_ensemble_scores[2], curr_ensemble_scores[2]],
    [LSTM_scores[3], GRU_scores[3], Attention_scores[3], CNN_scores[3], prev_ensemble_scores[3], curr_ensemble_scores[3]],
    [LSTM_scores[4], GRU_scores[4], Attention_scores[4], CNN_scores[4], prev_ensemble_scores[4], curr_ensemble_scores[4]],
    
]

df_metrics = pd.DataFrame(data=data, 
                          index=['MSE', 'MPA', 'Precision', 'Recall', 'F1-score', 'MDA'], 
                          columns=["LSTM", "GRU", "Attention", "CNN_LSTM", "Previous Blending Ensemble", "Current Blending Ensemble"])
print(df_metrics)
# Out:
#                  LSTM         GRU   Attention    CNN_LSTM  \
# MSE        288.575059  536.983799  372.974694  274.224113
# MPA          0.995130    0.992206    0.994521    0.995361
# Precision    0.250000    0.683333    0.450000    0.250000
# Recall       0.250000    0.625000    0.375000    0.250000
# F1-score     0.250000    0.645455    0.409091    0.250000
# MDA          0.250000    0.625000    0.375000    0.250000
#
#            Previous Blending Ensemble  Current Blending Ensemble
# MSE                        690.350914                 265.780541
# MPA                          0.991078                   0.994373
# Precision                    1.000000                   0.683333
# Recall                       0.625000                   0.625000
# F1-score                     0.769231                   0.645455
# MDA                          0.625000                   0.625000

# %%
# Charts
fig = plt.figure(figsize = (15, 7))

starting_time_idx = 95
models = ["LSTM", "GRU", "Attention", "CNN_LSTM", "Previous Blending Ensemble", "Current Blending Ensemble"]
colors = ['tab:orange', 'tab:green', 'tab:cyan', 'tab:purple', 'tab:grey', 'tab:red']
results = [y_hat_test_1, y_hat_test_2, y_hat_test_3, y_hat_test_4, ensemble_predicted_stock_price_prev, ensemble_predicted_stock_price]

# Actual Stock
plt.plot(stock_df.index[starting_time_idx:], stock_df['Adj Close'][starting_time_idx:], label = 'Actual Stock', c = 'tab:blue')

# Prediction
for i, r in enumerate(results):
    plt.plot(test_data.index[-9:], r, linestyle='dashed', label = '%s' % (models[i]), c = colors[i])

plt.xticks(stock_df.index[starting_time_idx::5], stock_df.index[starting_time_idx::5])
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # References
#
#
#
# 1.   Xinyi L., Yinchuan L., Hongyang Y., Liuqing Y., Xi- aoyang L. 2019. DP-LSTM: Differential Privacy- inspired LSTM for Stock Prediction Using Financial News. ArXiv, abs/1912.10806
# 2.   Yang L., Yi P. 2022. A novel ensemble deep learning model for stock prediction based on stock prices and news. International Journal of Data Science and Analytics, 13(2), 139-149.
